# %% [markdown]
# # Efficiency Plots for 2017:
#
# Check efficiency plots w.r.t the reference (noringer)

# %%
from kepler.pandas.menu       import ElectronSequence as Chain
from kepler.pandas.readers    import load, load_in_loop, load_hdf
from core import Efficiency, restore_efficiencies
from Gaugi import mkdir_p, progressbar
import numpy as np
import pandas as pd
import collections
import os
import rootplotlib as rpl
from pprint import pprint
from copy import deepcopy
import gc
from ROOT import kBlack,kBlue,kRed,kAzure,kGreen,kMagenta,kCyan,kOrange,kGray,kYellow,kWhite,TColor,gStyle

# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload
# %autoreload 2
# Out:
# Welcome to JupyROOT 6.16/00
# Using all sub packages with ROOT dependence
# INFO: Pandarallel will run on 40 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
#
# Applying ATLAS style settings...
#
# Applying ATLAS style settings...
#
# Applying ATLAS style settings...

# %% [markdown]
# ## 1) Read all files:

# %%
output_path = 'output/efficiencies'
mkdir_p(output_path)

# %%
eff_data17_Zee_ref  = restore_efficiencies( '../data/output/emulation/data17_Zee_efficiency_noringer.root' )
eff_data17_JF17_ref = restore_efficiencies( '../data/output/emulation/data17_JF17_efficiency_noringer.root')

# %%
eff_data17_Zee_v8  = restore_efficiencies( 'v8/output/emulation/data17_Zee_efficiency_v8.root'  )
eff_data17_Zee_v12 = restore_efficiencies( 'v12/output/emulation/data17_Zee_efficiency_v12.root')
eff_data17_Zee_v17 = restore_efficiencies( 'v17/output/emulation/data17_Zee_efficiency_v17.root')

# %%
eff_data17_JF17_v8  = restore_efficiencies( 'v8/output/emulation/data17_JF17_efficiency_v8.root'  )
eff_data17_JF17_v12 = restore_efficiencies( 'v12/output/emulation/data17_JF17_efficiency_v12.root')
eff_data17_JF17_v17 = restore_efficiencies( 'v17/output/emulation/data17_JF17_efficiency_v17.root')

# %%
def add_legend(x, y, legends):
    rpl.add_legend( legends,x,y,x+0.98,y+0.25,textsize=18, option='p' )

# %% [markdown]
# # Part III:
#
# ## Zee:

# %%
legends = [
            'with Ringer (v8)', 
            'with Ringer (v12)',
            'with Ringer (v17)',
          ]

# %% [markdown]
# ### HLT_e17

# %%
#colors = [kBlack,kBlue-4, kBlue-3, kBlue-2, kBlue-1]
colors = [kBlack, kBlue, kBlue, kBlue, kBlue]
#markers = [23, 24,25,26,27]
markers = [23, 24,25,26,32]

hists = [
            eff_data17_Zee_v8.profile('HLT_e17_lhvloose_nod0_ringer_v8_L1EM15VHI', 'HLT','highet'),
            eff_data17_Zee_v12.profile('HLT_e17_lhvloose_nod0_ringer_v12_L1EM15VHI', 'HLT','highet'),
            eff_data17_Zee_v17.profile('HLT_e17_lhvloose_nod0_ringer_v17_L1EM15VHI', 'HLT','highet'),
        ]

fig = rpl.create_canvas('my_canvas')
rpl.plot_profiles( hists, 'Offline isolated electron E_{T} [GeV]', colors, markers )
rpl.set_atlas_label(0.2,0.88,'Internal, pp data 2017 #sqrt{s}= 13TeV')
add_legend( 0.44,0.3, legends)
rpl.add_text( 0.35, 0.55, "HLT_e17_lhvloose_nod0_L1EM15VHI", textsize=0.04)
rpl.fix_yaxis_ranges( ignore_zeros=True, ignore_errors=True , ymaxf=1.2) 
fig.show()
fig.savefig(output_path+'/eff_emu_EGAM1_e17_ringer_v17_2017_HLT_highet.pdf')

# %%
#colors = [kBlack,kBlue-4, kBlue-3, kBlue-2, kBlue-1]
colors = [kBlack, kBlue, kBlue, kBlue, kBlue]
#markers = [23, 24,25,26,27]
markers = [23, 24,25,26,32]


hists = [
            eff_data17_Zee_v8.profile('HLT_e17_lhvloose_nod0_ringer_v8_L1EM15VHI', 'HLT','et'),
            eff_data17_Zee_v12.profile('HLT_e17_lhvloose_nod0_ringer_v12_L1EM15VHI', 'HLT','et'),
            eff_data17_Zee_v17.profile('HLT_e17_lhvloose_nod0_ringer_v17_L1EM15VHI', 'HLT','et'),
        ]

fig = rpl.create_canvas('my_canvas')
rpl.plot_profiles( hists, 'Offline isolated electron E_{T} [GeV]', colors, markers )
rpl.set_atlas_label(0.2,0.88,'Internal, pp data 2017 #sqrt{s}= 13TeV')
add_legend( 0.50,0.3, legends)
rpl.add_text( 0.4, 0.55, "HLT_e17_lhvloose_nod0_L1EM15VHI", textsize=0.04)
rpl.fix_yaxis_ranges( ignore_zeros=True, ignore_errors=True , ymaxf=1.2) 
fig.show()
fig.savefig(output_path+'/eff_emu_EGAM1_e17_ringer_v17_2017_HLT_et.pdf')

# %%
colors = [kBlack,kBlue-4, kBlue-3, kBlue-2, kBlue-1]

colors = [kBlack, kBlue, kBlue, kBlue, kBlue]

markers = [23, 24,25,26,32]
hists = [
            eff_data17_Zee_v8.profile('HLT_e17_lhvloose_nod0_ringer_v8_L1EM15VHI', 'HLT','eta'),
            eff_data17_Zee_v12.profile('HLT_e17_lhvloose_nod0_ringer_v12_L1EM15VHI', 'HLT','eta'),
            eff_data17_Zee_v17.profile('HLT_e17_lhvloose_nod0_ringer_v17_L1EM15VHI', 'HLT','eta'),
        ]

fig = rpl.create_canvas('my_canvas')
rpl.plot_profiles( hists, '#eta', colors, markers )
rpl.set_atlas_label(0.2,0.88,'Internal, pp data 2017 #sqrt{s}= 13TeV')
add_legend( 0.4,0.3, legends)
rpl.add_text( 0.35, 0.55, "HLT_e17_lhvloose_nod0_L1EM15VHI", textsize=0.04)
rpl.fix_yaxis_ranges( ignore_zeros=True, ignore_errors=True , ymaxf=1.1) 
fig.show()
fig.savefig(output_path+'/eff_emu_EGAM1_e17_ringer_v17_2017_HLT_eta.pdf')

# %% [markdown]
# ### HLT e28:

# %%
colors = [kBlack, kBlue, kBlue, kBlue, kBlue]
markers = [23,24,25,26,32]

hists = [
            eff_data17_Zee_v8.profile('HLT_e28_lhtight_nod0_ringer_v8_ivarloose'  , 'HLT','highet'),
            eff_data17_Zee_v12.profile('HLT_e28_lhtight_nod0_ringer_v12_ivarloose', 'HLT','highet'),
            eff_data17_Zee_v17.profile('HLT_e28_lhtight_nod0_ringer_v17_ivarloose', 'HLT','highet'),
        ]

fig = rpl.create_canvas('my_canvas')
rpl.plot_profiles( hists, 'Offline isolated electron E_{T} [GeV]', colors, markers )
rpl.set_atlas_label(0.2,0.88,'Internal, pp data 2017 #sqrt{s}= 13TeV')
add_legend( 0.25,0.25, legends)
rpl.add_text( 0.2, 0.8, "HLT_e28_lhtight_nod0_ivarloose", textsize=0.04)
rpl.fix_yaxis_ranges( ignore_zeros=True, ignore_errors=True , ymaxf=1.4) 
fig.show()
fig.savefig(output_path+'/eff_emu_EGAM1_e28_ringer_v17_2017_HLT_highet.pdf')

# %%
#colors = [kBlack,kBlue-4, kBlue-3, kBlue-2, kBlue-1]
colors = [kBlack, kBlue, kBlue, kBlue, kBlue]
#colors = [kBlue, kBlack, kBlack, kBlack, kBlack]
#markers = [23, 24,25,26,27]
markers = [23, 24,25,26,32]

hists = [
            eff_data17_Zee_v8.profile('HLT_e28_lhtight_nod0_ringer_v8_ivarloose'  , 'HLT','et'),
            eff_data17_Zee_v12.profile('HLT_e28_lhtight_nod0_ringer_v12_ivarloose', 'HLT','et'),
            eff_data17_Zee_v17.profile('HLT_e28_lhtight_nod0_ringer_v17_ivarloose', 'HLT','et'),
        ]

fig = rpl.create_canvas('my_canvas')
rpl.plot_profiles( hists, 'Offline isolated electron E_{T} [GeV]', colors, markers )
rpl.set_atlas_label(0.2,0.88,'Internal, pp data 2017 #sqrt{s}= 13TeV')
add_legend( 0.58,0.35, legends)
rpl.add_text( 0.51, 0.6, "HLT_e28_lhtight_nod0_ivarloose", textsize=0.04)
rpl.fix_yaxis_ranges( ignore_zeros=True, ignore_errors=True , ymaxf=1.2) 
fig.show()
fig.savefig(output_path+'/eff_emu_EGAM1_e28_ringer_v17_2017_HLT_et.pdf')

# %%
#colors = [kBlack,kBlue-4, kBlue-3, kBlue-2, kBlue-1]
colors = [kBlack, kBlue, kBlue, kBlue, kBlue]
#markers = [23, 24,25,26,27]
markers = [23, 24,25,26,32]

hists = [
            eff_data17_Zee_v8.profile('HLT_e28_lhtight_nod0_ringer_v8_ivarloose'  , 'HLT','eta'),
            eff_data17_Zee_v12.profile('HLT_e28_lhtight_nod0_ringer_v12_ivarloose', 'HLT','eta'),
            eff_data17_Zee_v17.profile('HLT_e28_lhtight_nod0_ringer_v17_ivarloose', 'HLT','eta'),
        ]

fig = rpl.create_canvas('my_canvas')
rpl.plot_profiles( hists, '#eta', colors, markers )
rpl.set_atlas_label(0.2,0.88,'Internal, pp data 2017 #sqrt{s}= 13TeV')
add_legend( 0.4,0.25, legends)
rpl.add_text( 0.38, 0.5, "HLT_e28_lhtight_nod0_ivarloose", textsize=0.04)
rpl.fix_yaxis_ranges( ignore_zeros=True, ignore_errors=True , ymaxf=1.1) 
fig.show()
fig.savefig(output_path+'/eff_emu_EGAM1_e28_ringer_v17_2017_HLT_eta.pdf')

# %% [markdown]
# ## Fakes:

# %% [markdown]
# ### HLT_e17:

# %%
colors = [kRed,kGray+1,kGray+1,kGray+1,kGray+1,]
markers = [23, 24,25,26,32]


hists = [
            eff_data17_JF17_v8.profile('HLT_e17_lhvloose_nod0_ringer_v8_L1EM15VHI'  , 'HLT','et'),
            eff_data17_JF17_v12.profile('HLT_e17_lhvloose_nod0_ringer_v12_L1EM15VHI', 'HLT','et'),
            eff_data17_JF17_v17.profile('HLT_e17_lhvloose_nod0_ringer_v17_L1EM15VHI', 'HLT','et'),
        ]

fig = rpl.create_canvas('my_canvas')
rpl.plot_profiles( hists, 'Offline isolated electron E_{T} [GeV]', colors, markers )
rpl.set_atlas_label(0.2,0.88,'Internal, pp data 2017 #sqrt{s}= 13TeV')
rpl.add_text(0.2, 0.80, "HLT_e17_lhvloose_nod0_L1EM15VHI", textsize=0.04)
rpl.add_text(0.2, 0.71, 'non-electron offline candidates', textsize=0.04)
add_legend( 0.64,0.65, legends)
rpl.set_ylabel('Trigger Efficiency (FastElectron)')
rpl.fix_yaxis_ranges( ignore_zeros=True, ignore_errors=True , ymaxf=1.65) 
fig.show()
fig.savefig(output_path+'/eff_emu_EGAM7_e17_ringer_v17_2017_HLT_et.pdf')

# %%
colors = [kRed,kGray+1,kGray+1,kGray+1,kGray+1,]
markers = [23, 24,25,26,32]


hists = [
            eff_data17_JF17_v8.profile('HLT_e17_lhvloose_nod0_ringer_v8_L1EM15VHI'  , 'L2','et'),
            eff_data17_JF17_v12.profile('HLT_e17_lhvloose_nod0_ringer_v12_L1EM15VHI', 'L2','et'),
            eff_data17_JF17_v17.profile('HLT_e17_lhvloose_nod0_ringer_v17_L1EM15VHI', 'L2','et'),
        ]

fig = rpl.create_canvas('my_canvas')
rpl.plot_profiles( hists, 'Offline isolated electron E_{T} [GeV]', colors, markers )
rpl.set_atlas_label(0.2,0.88,'Internal, pp data 2017 #sqrt{s}= 13TeV')
rpl.add_text(0.2, 0.80, "HLT_e17_lhvloose_nod0_L1EM15VHI", textsize=0.04)
rpl.add_text(0.2, 0.71, 'non-electron offline candidates', textsize=0.04)
add_legend( 0.64,0.65, legends)
rpl.set_ylabel('Trigger Efficiency (FastElectron)')
rpl.fix_yaxis_ranges( ignore_zeros=True, ignore_errors=True , ymaxf=1.65) 
fig.show()
fig.savefig(output_path+'/eff_emu_EGAM7_e17_ringer_v17_2017_L2_et.pdf')

# %%
colors = [kRed,kGray+1,kGray+1,kGray+1,kGray+1,]
markers = [23, 24,25,26,32]


hists = [
            eff_data17_JF17_v8.profile( 'HLT_e17_lhvloose_nod0_ringer_v8_L1EM15VHI' , 'L2','highet'),
            eff_data17_JF17_v12.profile('HLT_e17_lhvloose_nod0_ringer_v12_L1EM15VHI', 'L2','highet'),
            eff_data17_JF17_v17.profile('HLT_e17_lhvloose_nod0_ringer_v17_L1EM15VHI', 'L2','highet'),
        ]

fig = rpl.create_canvas('my_canvas')
rpl.plot_profiles( hists, 'Offline isolated electron E_{T} [GeV]', colors, markers )
rpl.set_atlas_label(0.2,0.88,'Internal, pp data 2017 #sqrt{s}= 13TeV')
rpl.add_text(0.2, 0.80, "HLT_e17_lhvloose_nod0_L1EM15VHI", textsize=0.04)
rpl.add_text(0.2, 0.71, 'non-electron offline candidates', textsize=0.04)
add_legend( 0.67,0.64, legends)
rpl.set_ylabel('Trigger Efficiency (FastElectron)')
rpl.fix_yaxis_ranges( ignore_zeros=True, ignore_errors=True , ymaxf=1.9) 
fig.show()
fig.savefig(output_path+'/eff_emu_EGAM7_e17_ringer_v17_2017_L2_highet.pdf')

# %%
colors = [kRed,kGray+1,kGray+1,kGray+1,kGray+1,]
markers = [23, 24,25,26,32]


hists = [
            eff_data17_JF17_v8.profile('HLT_e17_lhvloose_nod0_ringer_v8_L1EM15VHI'  , 'L2','eta'),
            eff_data17_JF17_v12.profile('HLT_e17_lhvloose_nod0_ringer_v12_L1EM15VHI', 'L2','eta'),
            eff_data17_JF17_v17.profile('HLT_e17_lhvloose_nod0_ringer_v17_L1EM15VHI', 'L2','eta'),
        ]

fig = rpl.create_canvas('my_canvas')
rpl.plot_profiles( hists, '#eta', colors, markers )
rpl.set_atlas_label(0.2,0.88,'Internal, pp data 2017 #sqrt{s}= 13TeV')
rpl.add_text(0.2, 0.80, "HLT_e17_lhvloose_nod0_L1EM15VHI", textsize=0.04)
rpl.add_text(0.2, 0.71, 'non-electron offline candidates', textsize=0.04)
add_legend( 0.4,0.42, legends)
rpl.set_ylabel('Trigger Efficiency (FastElectron)')
rpl.fix_yaxis_ranges( ignore_zeros=True, ignore_errors=True , ymaxf=1.6) 
fig.show()
fig.savefig(output_path+'/eff_emu_EGAM7_e17_ringer_v17_2017_L2_eta.pdf')

# %% [markdown]
# # HLT_e28:

# %%
colors = [kRed,kGray+1,kGray+1,kGray+1,kGray+1,]
markers = [23, 24,25,26,32]


hists = [
            eff_data17_JF17_v8.profile('HLT_e28_lhtight_nod0_ringer_v8_ivarloose', 'L2','et'),
            eff_data17_JF17_v12.profile('HLT_e28_lhtight_nod0_ringer_v12_ivarloose', 'L2','et'),
            eff_data17_JF17_v17.profile('HLT_e28_lhtight_nod0_ringer_v17_ivarloose', 'L2','et'),
        ]

fig = rpl.create_canvas('my_canvas')
rpl.plot_profiles( hists, 'Offline isolated electron E_{T} [GeV]', colors, markers )
rpl.set_atlas_label(0.2,0.88,'Internal, pp data 2017 #sqrt{s}= 13TeV')
rpl.add_text(0.2, 0.80, "HLT_e28_lhtight_nod0_ivarloose", textsize=0.04)
rpl.add_text(0.2, 0.71, 'non-electron offline candidates', textsize=0.04)
add_legend( 0.64,0.64, legends)
rpl.set_ylabel('Trigger Efficiency (FastElectron)')
rpl.fix_yaxis_ranges( ignore_zeros=True, ignore_errors=True , ymaxf=1.65) 
fig.show()
fig.savefig(output_path+'/eff_emu_EGAM7_e28_ringer_v17_2017_L2_et.pdf')

# %%
colors = [kRed,kGray+1,kGray+1,kGray+1,kGray+1,]
markers = [23, 24,25,26,32]


hists = [
            eff_data17_JF17_v8.profile('HLT_e28_lhtight_nod0_ringer_v8_ivarloose', 'L2','highet'),
            eff_data17_JF17_v12.profile('HLT_e28_lhtight_nod0_ringer_v12_ivarloose', 'L2','highet'),
            eff_data17_JF17_v17.profile('HLT_e28_lhtight_nod0_ringer_v17_ivarloose', 'L2','highet'),
        ]

fig = rpl.create_canvas('my_canvas')
rpl.plot_profiles( hists, 'Offline isolated electron E_{T} [GeV]', colors, markers )
rpl.set_atlas_label(0.2,0.88,'Internal, pp data 2017 #sqrt{s}= 13TeV')
rpl.add_text(0.2, 0.80, "HLT_e28_lhtight_nod0_ivarloose", textsize=0.04)
rpl.add_text(0.2, 0.71, 'non-electron offline candidates', textsize=0.04)
add_legend( 0.23,0.45, legends)
rpl.set_ylabel('Trigger Efficiency (FastElectron)')
rpl.fix_yaxis_ranges( ignore_zeros=True, ignore_errors=True , ymaxf=2) 
fig.show()
fig.savefig(output_path+'/eff_emu_EGAM7_e28_ringer_v17_2017_L2_highet.pdf')

# %%
colors = [kRed,kGray+1,kGray+1,kGray+1,kGray+1,]
markers = [23, 24,25,26,32]


hists = [
            eff_data17_JF17_v8.profile('HLT_e28_lhtight_nod0_ringer_v8_ivarloose', 'L2','eta'),
            eff_data17_JF17_v12.profile('HLT_e28_lhtight_nod0_ringer_v12_ivarloose', 'L2','eta'),
            eff_data17_JF17_v17.profile('HLT_e28_lhtight_nod0_ringer_v17_ivarloose', 'L2','eta'),
        ]

fig = rpl.create_canvas('my_canvas')
rpl.plot_profiles( hists, 'Offline isolated electron E_{T} [GeV]', colors, markers )
rpl.set_atlas_label(0.2,0.88,'Internal, pp data 2017 #sqrt{s}= 13TeV')
rpl.add_text(0.2, 0.80, "HLT_e28_lhtight_nod0_ivarloose", textsize=0.04)
rpl.add_text(0.2, 0.71, 'non-electron offline candidates', textsize=0.04)
add_legend( 0.4,0.46, legends)
rpl.set_ylabel('Trigger Efficiency (FastElectron)')
rpl.fix_yaxis_ranges( ignore_zeros=True, ignore_errors=True , ymaxf=1.8) 
fig.show()
fig.savefig(output_path+'/eff_emu_EGAM7_e28_ringer_v17_2017_L2_eta.pdf')
